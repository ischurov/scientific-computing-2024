# %% [markdown]
# ## Data Visualization
# ## `Assignment 4: Matplotlib`
#
# Your task is to create a comprehensive and visually appealing visualization of stock market data using Matplotlib. You can choose and split the data in any manner that you find interesting and insightful.
#
# ## Requirements
# The final visualization should include the following customizations:
#
# 1. **Multiple Subplots or GridSpec Layouts** `(1 point)`
#    - Utilize multiple subplots or GridSpec to organize your figure.
#
# 2. **Diverse Visualization Methods** `(2 points)`
#    - Incorporate various types of plots (e.g., line, scatter, histogram, 3D plots, etc.) to represent the data effectively.
#
# 3. **Informative Labels and Titles** `(1 point)`
#    - Add clear and descriptive labels and titles to all axes and plots.
#
# 4. **Ticks and TickLabels Customization** `(1 point)`
#    - Customize the appearance of ticks and tick labels for better readability and presentation.
#
# 5. **Adjusting Axes Limits and Scales** `(1 point)`
#    - Modify the axes limits and scales to enhance the data representation.
#
# 6. **Advanced Plotting Techniques** `(2 points)`
#    - Apply any advanced plotting options not covered in the lecture, along with an explanation of their benefits.
#
# ## Aesthetic Evaluation
# The overall aesthetics of your figure will be subjectively evaluated. The top three visually appealing figures will receive an additional `2 bonus points`.
#
# ## Restrictions
# - You are only allowed to use NumPy, Matplotlib, and Pandas (for data reading and processing) Python packages.
#
# ## Submission
# - Your final result should be a Jupyter Notebook that, when executed linearly, reproduces your figure.
# - Save your final figure in the `figures/` directory within the same folder as your notebook in the `pdf`.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/World-Stock-Prices-Dataset.csv")
df["Date"] = pd.to_datetime(df["Date"], utc=True)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("data/World-Stock-Prices-Dataset.csv")
#       2 df["Date"] = pd.to_datetime(df["Date"], utc=True)
#       4 df.head()
#
# ...

# %%
df[df["Brand_Name"] == "crocs"].plot(x="Date", y="High")
# Out:
# <Axes: xlabel='Date'>
